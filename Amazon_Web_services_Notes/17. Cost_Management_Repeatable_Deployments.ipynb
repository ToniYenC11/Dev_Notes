# %% [markdown]
# # Cost Management and Best Practices

# %% [markdown]
# ## AWS Cost Management Tools and Services

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - **Cost Explorer** - Graphs, visualized, forecasts.
#
# - **Billing** - Status
# - **Budgets** - Set custom cost and usage budgets
# - **CloudWatch** - Monitor user charge, alert on threshold

# %% [markdown]
# ## AWS Billing Dashboard

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Use for services

# %% [markdown]
# ## Cost Explorer

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Visualize, forecast

# %% [markdown]
# ## Budgets

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Alert when exceeds amount
#
# - It DOES NOT STOP the services themselves

# %% [markdown]
# ## Cost and Usage Reports

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## CloudWatch Billing Alarms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Designing for Cost Reduction

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - **Proactive** - Setting up CloudWatch
#
# - **Reactive** - Not setting up any of the two

# %% [markdown]
# ## Using a Stopinator Script

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## AWS Trusted Advisor

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # AWS Support Services

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Benefits of AWS Support Services

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## How AWS Support Works

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## AWS Support Technology and Programs

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## The Role of AWS Support

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Support Plans

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## AWS Trusted Advisor

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Configuration Management in the Cloud

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Configuration Software

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # AMI Building Strategy

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ## Creating AMIs

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Copying AMIs

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ## Checkpoint Questions

# %% [markdown]
# 1. What is an Amazon Machine Image (AMI)?
#
# 2. What is the purpose of the User Data option?
#
# 3. A new AMI is created in the us-east-1 Region and copied to the us-east-2 Region. A script that was used to launch EC2 instances in us-east-1 is then used to launch instances in us-east-2. When the script is run, it fails.What could be the problem?

# %% [markdown]
# # EC2 Launch Templates

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lab 189 - Optimize Utilization

# %% [markdown]
# ### Configure AWS CLI

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Connect via SSH to CLI HOST:
#
# ![image-2.png](attachment:image-2.png)
#
# In *CafeInstance*, uninstall MariaDB and resize instance:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# In the CLI Host Instance:
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Change the instance type to `t3.micro`:
#
# ![image-4.png](attachment:image-4.png)
#
# Start instance:
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ## Use the AWS Pricing Calculator

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
