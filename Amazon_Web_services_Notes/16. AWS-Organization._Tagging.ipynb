# %% [markdown]
# # AWS Organizations

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - An **oragnizational unmit** (OU) is a container for accounts within a root. An OU can also contain other OUs, which enables you to create a hierarchy that looks like an upside-down tree.
#
# - When you attach a policy to one of the nodes in the hierarchy, it flows down and affects all the branches and leaves.
#
# - An OU can have only one parent and, currently, each account can be a member of exactly one OU.
#
# - An account is a standard AWS account that contains your AWS resources. You can attach a policy to an account to apply controls to only that one account.

# %% [markdown]
# ## Features and Benefits

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Security with AWS Organizations

# %% [markdown]
# - Control access with AWS Identity and Access Management (IAM).
#
# - IAM policies enable yout to allow/deny access to AWS services for users, groups, roles
# - **Service control policies** (SCPs) enable you to allow or deny access to AWS services for individuals or group accounts in an organizational unit
#     - SCP > IAM policies

# %% [markdown]
# ## Best Practices

# %% [markdown]
# ![|](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Additional Notes

# %% [markdown]
# Typical organization:
#
# ![image.png](attachment:image.png)
#
# SCP: Attached to the organizational unit
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Tagging

# %% [markdown]
# - Key-value pair that can be attached to an AWS resource
#
# - Enables to identify and categorize resources
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Characteristics of Tags

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## AWS Config and Tagging

# %% [markdown]
# - Use `required-tags` managed rule
#
# - Specify the required tag key (and optionally the required value).
# - Evaluates rules and identifies non-compliant resources.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Tagging in AWS CLI

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Enforce Tagging with IAM

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Best Practices

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Lab 188 - Managing Resources with Tagging

# %% [markdown]
# ## Using Tags to Manage Resources

# %% [markdown]
# Finding Development Instances for the Project:
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# Use the `--query` parameter to limit the output of the previous command to only the instance ID of the discovered instance:
#
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# #### Changing Version Tag for Development Process

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Stop and Start Resources by Tag

# %% [markdown]
# Below is an example of a `stopinator.php`
#
# ![image.png](attachment:image.png)
#
# Result:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Challenge: Stop Noncompliant Instances

# %% [markdown]
# Using AWS SDK for Python:
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
