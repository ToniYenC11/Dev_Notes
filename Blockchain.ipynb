# %% [markdown]
# # Blockchain
#
# Database/ledger distributed across comupters' network nodes

# %% [markdown]
# ## Self-Sovereign Identity
#
# - Decentralized approach to managing PII instead of a central authority to control and verify identity.
#
# - Individuals have direct control of their own data
